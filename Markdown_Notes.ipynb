# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshKhatri01/Markdown-Notes/blob/main/Markdown_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 📌 **Jupyter Notebook Markdown Cheatsheet - Hinglish Notes**
#
# Jupyter Notebook me **Markdown** ka use text formatting, headings, lists, links, images aur code blocks likhne ke liye hota hai. Yeh data science aur machine learning me **notes likhne aur reports banane** ke liye kaafi useful hai.
#
# ---
#
# ## **1️⃣ Headings (Title aur Subheadings)**
# Markdown me **heading likhne ke liye `#` ka use** hota hai.
# Jitne zyada `#`, utni chhoti heading size.
#
# ```markdown
# # Sabse Badi Heading (H1)
# ## Doosri Badi Heading (H2)
# ### Teesri Badi Heading (H3)
# #### Chauthi Heading (H4)
# ##### Paanchvi Heading (H5)
# ###### Chhathi Heading (H6)
# ```
#
# ➡️ Example:
# # Ye H1 Heading Hai
# ## Ye H2 Heading Hai
# ### Ye H3 Heading Hai
#
# ---
#
# ## **2️⃣ Bold aur Italic Text**
# Kisi text ko **bold** ya *italic* me likhne ke liye `**` ya `*` ka use hota hai.
#
# ```markdown
# **Yeh Bold Text Hai**
# *Yeh Italic Text Hai*
# ***Yeh Bold + Italic Hai***
# ```
#
# ➡️ Example:
# **Yeh Bold Hai**
# *Yeh Italic Hai*
# ***Yeh Bold + Italic Hai***
#
# ---
#
# ## **3️⃣ Lists (Ordered & Unordered)**
# ### 📍 **Unordered List (Bullet Points)**
# Bullet points banane ke liye `-`, `+`, ya `*` ka use kar sakte hain.
#
# ```markdown
# - Apple
# - Mango
# - Banana
#
# + Car
# + Bike
# + Bus
#
# * Python
# * Java
# * C++
# ```
#
# ➡️ Example:
# - Apple
# - Mango
# - Banana
#
# + Car
# + Bike
# + Bus
#
# * Python
# * Java
# * C++
#
# ### 📍 **Ordered List (Numbering)**
# ```markdown
# 1. First Item
# 2. Second Item
# 3. Third Item
# ```
#
# ➡️ Example:
# 1. First Item
# 2. Second Item
# 3. Third Item
#
# ---
#
# ## **4️⃣ Links aur Images**
# ### 📍 **Hyperlink (Link Daalna)**
# ```markdown
# [Google Search](https://www.google.com)
# ```
# ➡️ Example: [Google Search](https://www.google.com)
#
# ### 📍 **Image Insert Karna**
# ```markdown
# ![Alt Text](https://www.example.com/image.jpg)
# ```
# ➡️ Example:
# ![Sample Image](https://upload.wikimedia.org/wikipedia/commons/6/69/June_odd-eyed-cat.jpg)
#
# ---
#
# ## **5️⃣ Code Blocks (Inline aur Multiline Code)**
# ### 📍 **Inline Code (Ek Line Code)**
# ```markdown
# `print("Hello World")`
# ```
# ➡️ Example: `print("Hello World")`
#
# ### 📍 **Multiline Code (Multiple Lines Ka Code)**
# ```markdown
# ```
# def hello():
#     print("Hello, World!")
# ```
# ```
# ➡️ Example:
# ```
# def hello():
#     print("Hello, World!")
# ```
#
# ---
#
# ## **6️⃣ Tables (Table Banana)**
# Table banane ke liye `|` aur `-` ka use hota hai.
#
# ```markdown
# | Name  | Age | City     |
# |-------|----|---------|
# | Rahul | 22 | Delhi   |
# | Priya | 25 | Mumbai  |
# | Aman  | 30 | Kolkata |
# ```
#
# ➡️ Example:
#
# | Name  | Age | City     |
# |-------|----|---------|
# | Rahul | 22 | Delhi   |
# | Priya | 25 | Mumbai  |
# | Aman  | 30 | Kolkata |
#
# ---
#
# ## **7️⃣ Horizontal Line (Separator Line)**
# Agar ek line ke beech me separator dalna ho toh `---`, `***` ya `___` ka use kar sakte hain.
#
# ```markdown
# ---
# ***
# ___
# ```
#
# ➡️ Example:
# ---
# ***
# ___
#
# ---
#
# ## **8️⃣ Blockquotes (Quote ya Important Note Dikhana)**
# Agar kisi **important note ya quote** ko highlight karna ho toh `>` ka use kar sakte hain.
#
# ```markdown
# > Ye ek important note hai!
# ```
#
# ➡️ Example:
# > Ye ek important note hai!
#
# ---
#
# ## **9️⃣ Checkbox (Task List Banana)**
# ```markdown
# - [x] Task 1 (Complete)
# - [ ] Task 2 (Pending)
# - [ ] Task 3 (Pending)
# ```
#
# ➡️ Example:
# - [x] Task 1 (Complete)
# - [ ] Task 2 (Pending)
# - [ ] Task 3 (Pending)
#
# ---
